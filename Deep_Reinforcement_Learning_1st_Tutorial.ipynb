# %% [markdown]
# <a href="https://colab.research.google.com/github/hungryphobic/RL/blob/main/Deep_Reinforcement_Learning_1st_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 0 : install dependencies

# %%
# !pip install tensorflow==2.3.0
# !pip install gym
# !pip install keras
# !pip install keras-rl2

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %% [markdown]
# # Step 1 :Test random enviroment witj OpenAI Gym

# %%
import gym
import random

# %%
env = gym.make('CartPole-v0')
states = env.observation_space.shape[0]
actions = env.action_space.n

# %%
actions
# Out:
# 2

# %%
episodes = 10
for episodes in range(1,  episodes+1):
  state =env.reset()
  done = False
  score = 0

  while not done:
    env.render()
    action = random.choice([0,1])
    n_state, reward, done, info=env.step(action)
    score+=reward
  print('Episode:{} Score:{}'.format(episode, score))

# %% [markdown]
# # Step 2 : Create Deep Learning model with Keras

# %% [markdown]
# # Step 3 : Build agent with Keras-RL
#
# ---

# %% [markdown]
# # Step 4 : Reloading Agent from memory
